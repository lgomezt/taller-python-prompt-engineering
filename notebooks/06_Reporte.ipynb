# %% [markdown]
# # 06 — Reporte final
#
# **Tu prompt para Cursor**: el de la seccion 10 del notebook `02_Tutorial_Cursor.ipynb`.
#
# Objetivo: integrar todos los outputs intermedios en un reporte ejecutivo
# (`outputs/final_report.md`) legible por un decano.
#
# **Entrada**:
# - `outputs/eda_summary.md`
# - `outputs/cleaning_report.md`
# - `outputs/model_report.md`
# - `outputs/figures/model/*.png`
#
# **Salida**:
# - `outputs/final_report.md`
#
# Este notebook idealmente **no tiene codigo**: el reporte es markdown. Si Cursor
# necesita correr algo para validar (ej. listar las figuras existentes), puede usar
# la celda de abajo.

# %%
# Setup: imports + path al repo
import warnings
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def repo_root() -> Path:
    cwd = Path.cwd()
    for candidate in [cwd, cwd.parent]:
        if (candidate / "data").is_dir():
            return candidate
    raise FileNotFoundError("No se encontro la carpeta data/. Abri el notebook desde el repo.")

ROOT = repo_root()
DATA_DIR = ROOT / "data"
OUTPUTS_DIR = ROOT / "outputs"
OUTPUTS_DIR.mkdir(exist_ok=True)
(OUTPUTS_DIR / "figures").mkdir(exist_ok=True)

pd.set_option("display.max_columns", 50)
warnings.filterwarnings("ignore", category=FutureWarning)
sns.set_theme(style="whitegrid")

print("Repo:", ROOT)

# %% [markdown]
# ## 4.1 Generar `outputs/final_report.md`

# %%
# TODO (Cursor): componer outputs/final_report.md integrando eda_summary.md +
#                cleaning_report.md + model_report.md. Estructura:
#                  1. Resumen ejecutivo (120 palabras max)
#                  2. Metodologia (1-2 parrafos)
#                  3. Resultados (tablas + figuras linkeadas)
#                  4. Limitaciones (3-5 bullets honestos)
#                  5. Recomendaciones (3 bullets concretos)
#                Tono profesional, sin exagerar. Publico: decano de economia.

# %% [markdown]
# ## 4.2 Validacion opcional

# %%
# TODO (Cursor): listar archivos en outputs/ para verificar que el reporte
#                referencia figuras que si existen.
