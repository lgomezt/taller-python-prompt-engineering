# %% [markdown]
# # 03 — Exploracion (EDA)
#
# **Tu prompt para Cursor**: el **PROMPT RECETA #1** del notebook `02_Tutorial_Cursor.ipynb`,
# seccion 7.2.
#
# Objetivo de este notebook: explorar `admissions.csv` y `bmi.csv` **por separado**,
# SIN limpiar todavia. Reportar: shape, tipos, NAs, outliers, duplicados, cardinalidad, rangos.
#
# **Entrada**: `data/admissions.csv`, `data/bmi.csv`
#
# **Salida**:
# - `outputs/eda_summary.md` — resumen de hallazgos + preguntas abiertas para la limpieza
# - `outputs/figures/eda/*.png` — figuras opcionales
#
# **Siguiente paso**: `04_Limpieza.ipynb`

# %%
# Setup: imports + path al repo
import warnings
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def repo_root() -> Path:
    cwd = Path.cwd()
    for candidate in [cwd, cwd.parent]:
        if (candidate / "data").is_dir():
            return candidate
    raise FileNotFoundError("No se encontro la carpeta data/. Abri el notebook desde el repo.")

ROOT = repo_root()
DATA_DIR = ROOT / "data"
OUTPUTS_DIR = ROOT / "outputs"
OUTPUTS_DIR.mkdir(exist_ok=True)
(OUTPUTS_DIR / "figures").mkdir(exist_ok=True)

pd.set_option("display.max_columns", 50)
warnings.filterwarnings("ignore", category=FutureWarning)
sns.set_theme(style="whitegrid")

print("Repo:", ROOT)

# %% [markdown]
# ## 1.1 Admisiones — `data/admissions.csv`

# %%
# TODO (Cursor): cargar data/admissions.csv, shape, dtypes, memoria.

# %%
# TODO (Cursor): NAs por columna (conteo + %).

# %%
# TODO (Cursor): describe() + outliers IQR en numericas.

# %%
# TODO (Cursor): value_counts + cardinalidad en categoricas.

# %%
# TODO (Cursor): duplicados (filas completas + por Student_ID).

# %%
# TODO (Cursor): validacion de rangos razonables segun el prompt.

# %%
# TODO (Cursor): 5 filas con al menos un problema detectado.

# %% [markdown]
# ### Hallazgos admissions
#
# (Cursor: 3-5 bullets.)

# %% [markdown]
# ## 1.2 BMI — `data/bmi.csv`

# %%
# TODO (Cursor): mismo analisis pero para bmi.csv (separador ';').

# %% [markdown]
# ### Hallazgos bmi
#
# (Cursor: 3-5 bullets.)

# %% [markdown]
# ## 1.3 Exportar `outputs/eda_summary.md`

# %%
# TODO (Cursor): escribir outputs/eda_summary.md con:
#   - hallazgos clave de ambos datasets
#   - preguntas abiertas que hay que decidir antes de limpiar
